# %% [markdown]
# # Exploración Inicial de Datos - ODS.fit
#
# **Objetivo:** Realizar un análisis exploratorio inicial del archivo de datos educativos.
#
# **Fecha:** 2026-04-14
#
# **Autores:** ODS.fit (Vanessa Bustos, Gustavo Pérez, Elías Pérez)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuración de visualización
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# %matplotlib inline

# %% [markdown]
# ## 1. Carga de Datos
#
# **Nota:** El archivo original tiene un problema en la columna `n_entidad`.
# Primero debemos ejecutar el script de limpieza.

# %%
# Ejecutar script de limpieza primero
# !python ../scripts/limpieza_datos.py

# Luego cargar datos limpios
# df = pd.read_csv('../datos/processed/archivo_agrupado_limpio.csv')

# %% [markdown]
# ## 2. Exploración Básica

# %%
# Información general del dataset
# print("Dimensiones:", df.shape)
# print("\nColumnas:", df.columns.tolist())
# print("\nPrimeras filas:")
# df.head()

# %% [markdown]
# ## 3. Análisis por Nivel Educativo

# %%
# Totales por nivel educativo
# nivel_stats = df.groupby('nivel').agg({
#     'insc_t': 'sum',
#     'tot_doc': 'sum',
#     'egre_tot': 'sum'
# })
# nivel_stats

# %% [markdown]
# ## 4. Análisis de Género (ODS 5)

# %%
# Distribución por género
# df['prop_hombres'] = df['hom_t'] / df['insc_t'] * 100
# df['prop_mujeres'] = df['muj_t'] / df['insc_t'] * 100

# %% [markdown]
# ## 5. Próximos Pasos
#
# 1. Limpiar el archivo de datos
# 2. Completar análisis exploratorio
# 3. Identificar estados con mayores brechas
# 4. Crear visualizaciones para el dashboard
